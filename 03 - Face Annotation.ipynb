# %%
import cv2
import numpy as np



def draw_rectangle(event, x, y, flags, params):
    
    coordinates = list()
    subcorr = list()

    global ix, iy, drawing ,counter

    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix, iy = x, y
        
    #elif event == cv2.EVENT_MOUSEMOVE:
    #    if drawing == True:
    #        x=x
    #        y=y
    #        cv2.rectangle(img, pt1 = (ix, iy), pt2 = (x, y), 
    #                      color = (87, 184, 237), thickness = 1)
            
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        cv2.rectangle(img, pt1 = (ix, iy), pt2 = (x, y), 
                          color = (87, 184, 237), thickness = 1)
        cv2.putText(img, text = "%s"%counter, org = ((ix+x)//2,(iy+y)//2),fontFace = cv2.FONT_HERSHEY_DUPLEX,
                    fontScale = 1, color = (255, 255, 255), thickness = 2, lineType = cv2.LINE_AA)
        
        subcorr.append(ix)
        subcorr.append(iy)
        subcorr.append(x)
        subcorr.append(y)
        cor_dict = {counter : subcorr}
        print(cor_dict)
        counter+=1

# %%
# Step 1. Define callback function
drawing = False
ix = -1
iy = -1
counter =1

# %%
# Step 2. Call the window
import matplotlib.pyplot as plt
img = cv2.imread('/home/luminar/Desktop/data/fifa/bernardosilva.png')
plt.imshow(img)

# %%
cv2.namedWindow('card2', cv2.WINDOW_AUTOSIZE)
cv2.setMouseCallback('card2', draw_rectangle)
# Step 3. Execution 
while True: 
    cv2.imshow('card2', img)
    if cv2.waitKey(10) & 0xFF == 27:
        break

cv2.destroyAllWindows()
# Out:
# {1: [113, 318, 494, 423]}

# %%
img.shape
